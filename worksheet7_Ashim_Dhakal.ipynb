# %% [markdown]
# <a href="https://colab.research.google.com/github/AshimDhakal7/Concept-and-technologies-of-AI/blob/main/worksheet7_Ashim_Dhakal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ashim Dhakal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Data Sets/diabetes.csv")

# %% [markdown]
# **DATA INTRO**
# The National Institute of Diabetes and Digestive and Kidney Diseases gave this dataset its original source. Based on specific diagnostic metrics included in the dataset, the dataset's goal is to diagnostically predict whether or not a patient has diabetes. These examples were chosen from a bigger database under a number of restrictions. Specifically, every patient here is a female of Pima Indian descent who is at least 21 years old.

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
print("missing values in the dataset:-")
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# missing values in the dataset:-
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
print("duplicate values in the dataset:-")
missing_values = df.duplicated().sum()
print(missing_values)
# Out:
# duplicate values in the dataset:-
# 0

# %%
# Bar graph
plt.figure(figsize=(7, 5))
blood_pressure_counts = df['BloodPressure'].value_counts().sort_index()
blood_pressure_counts.plot(kind='bar', color="purple")
plt.title("Bar Graph of BloodPressure Distribution")
plt.xlabel("BloodPressure")
plt.ylabel("Count")

# Boxplot
plt.figure(figsize=(7, 5))
sns.boxplot(x=df['BloodPressure'], color="blue")
plt.title("Boxplot of BloodPressure")
plt.show()


# Histogram
plt.figure(figsize=(7, 5))
plt.hist(df['BloodPressure'], bins=20, color="green")
plt.title("Histogram of BloodPressure")
plt.xlabel("BloodPressure")
plt.ylabel("Frequency")
plt.show()



# Scatterplot
sns.scatterplot(x='BloodPressure', y='Outcome', data=df, color="orange")
plt.title("Scatterplot of BloodPressure vs Outcome")
plt.xlabel("BloodPressure")
plt.ylabel("Outcome")
plt.show()

# %%
#line plot
plt.figure(figsize=(7, 5))
sns.lineplot(x=df.index, y=df['BloodPressure'], color="red")
plt.title("Line Plot of BloodPressure")
plt.xlabel("Index")
plt.ylabel("BloodPressure")
# Out:
# Text(0, 0.5, 'BloodPressure')

# %%
x=df.drop(columns=['BloodPressure'])
y=df['BloodPressure']

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
X_train, X_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R=squared: {r2}')
# Out:
# Mean Squared Error: 402.8523890426408
# R=squared: 0.19403775986668126
